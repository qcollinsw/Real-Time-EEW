# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import optim
from torch import nn
from torch.utils.data import DataLoader, TensorDataset, random_split, WeightedRandomSampler
from torch.optim.lr_scheduler import StepLR

from tqdm import tqdm

import torchvision

import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms


# !pip install torchmetrics
from torchmetrics import Accuracy

import time
# Out:
# Collecting torchmetrics
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (26.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.11.0+cu128)
# Collecting lightning-utilities>=0.15.3 (from torchmetrics)
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.15.3->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.29.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.9.6)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->torchmetrics) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 13.5 MB/s eta 0:00:00
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Installing collected packages: lightning-utilities, torchmetrics
# Successfully installed lightning-utilities-0.15.3 torchmetrics-1.9.0

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
counts = [1786, 186, 292]
class_weights = [1/count for count in counts]
batches = 16


param = 'origin class'

training_file = 'train.pt'
training_data = torch.load(training_file, map_location = device)
training_waveforms = training_data['raw waves']
training_labels    = training_data[param]
targets = torch.argmax(torch.squeeze(training_labels, dim = 1), dim = 1)
sample_weights = [class_weights[t] for t in targets]
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True
)
trainingset = TensorDataset(training_waveforms, training_labels)
training = DataLoader(trainingset, batch_size=batches, sampler = sampler)

testing_file  = 'test.pt'
testing_data  = torch.load(testing_file, map_location = device)
testing_waveforms = testing_data['raw waves']
testing_labels    = testing_data[param]
testingset  = TensorDataset(testing_waveforms, testing_labels)
testing = DataLoader(testingset, batch_size=batches, shuffle = False)

# %%
classes = 3

# Define Model
class CNN(nn.Module):

    def __init__(self, num_features):
        super(CNN, self).__init__()

        self.conv1   = nn.Conv2d(1,    out_channels = 16,  kernel_size =(3,7), padding ='same')
        self.conv2   = nn.Conv2d(16,   out_channels = 64,  kernel_size =(3,7), padding ='same')
        self.conv3   = nn.Conv2d(64,   out_channels = 64,  kernel_size =(3,7), padding ='same')
        self.conv4   = nn.Conv2d(64,   out_channels = 128, kernel_size =(3,7), padding ='same')
        self.conv5   = nn.Conv2d(128,  out_channels = 256, kernel_size =(3,7), padding ='same')
        self.pool    = nn.MaxPool2d(kernel_size = 2, stride = 2, padding = 1)
        self.bn1     = nn.BatchNorm2d(16)
        self.bn2     = nn.BatchNorm2d(64)
        self.bn3     = nn.BatchNorm2d(64)
        self.bn4     = nn.BatchNorm2d(128)
        self.bn5     = nn.BatchNorm2d(256)
        self.relu    = nn.ReLU()
        self.softmax = nn.Softmax(dim=-1)
        self.dropout = nn.Dropout(p=0.5)

        self.fullyconnected = nn.LazyLinear(classes)

    def forward(self,x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv4(x)
        x = self.bn4(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv5(x)
        x = self.bn5(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = torch.flatten(x, start_dim = 1)
        x = self.fullyconnected(x)
        x = self.softmax(x)

        return x

# %%
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)

# %%
# Construct model
model = CNN(classes)
model.to(device)

print(model)

# define optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=100, gamma=0.1)
weights = torch.tensor([1.0, 1.0, 1.3]).to(device)
criterion = nn.CrossEntropyLoss(weight = weights)
# Out:
# CNN(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv2): Conv2d(16, 64, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv5): Conv2d(128, 256, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (softmax): Softmax(dim=-1)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fullyconnected): LazyLinear(in_features=0, out_features=3, bias=True)
# )

# %%
epochs = 150
model.train()

avg_losses_per_batch = []
batch_accuracies = []

start_time = time.perf_counter()

# Training
for epoch in range(epochs):

    accuracy_training = Accuracy(task="multiclass", num_classes = classes).to(device)
    all_preds = []
    all_labels = []
    batch_losses = []
    print(f"Epoch [{epoch + 1}/{epochs}]")

    for i, data in enumerate(training):

        raw_data, labels = data

        labels = torch.squeeze(labels)
        _, truth = torch.max(labels, 1)

        classification = model(raw_data.float())

        _, preds = torch.max(classification, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(truth.cpu().numpy())

        loss = criterion(classification, truth)
        accuracy_training(preds, truth)


        batch_losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    scheduler.step()

    training_accuracy = accuracy_training.compute()
    print(f"Training accuracy: {training_accuracy}")

    batch_accuracies.append(training_accuracy.cpu().item())
    avg_losses_per_batch.append(np.mean(batch_losses))
    print(f"Average loss per batch: {np.mean(batch_losses)}")
end_time = time.perf_counter()
print(f"Training time: {end_time - start_time}")
# Out:
# Epoch [1/150]
# Training accuracy: 0.5331271886825562
# Average loss per batch: 1.0015753646131973
# Epoch [2/150]
# Training accuracy: 0.601590096950531
# Average loss per batch: 0.9529632308953245
# Epoch [3/150]
# Training accuracy: 0.6457597017288208
# Average loss per batch: 0.9034385861645282
# Epoch [4/150]
# Training accuracy: 0.6409010887145996
# Average loss per batch: 0.8955016665055718
# Epoch [5/150]
# Training accuracy: 0.6568021178245544
# Average loss per batch: 0.8881870021282787
# Epoch [6/150]
# Training accuracy: 0.662102460861206
# Average loss per batch: 0.8993074721853498
# Epoch [7/150]
# Training accuracy: 0.6749116778373718
# Average loss per batch: 0.8916927341004492
# Epoch [8/150]
# Training accuracy: 0.7190812826156616
# Average loss per batch: 0.8503288832348836
# Epoch [9/150]
# Training accuracy: 0.7045053243637085
# Average loss per batch: 0.8464926082483479
# Epoch [10/150]
# Training accuracy: 0.7195229530334473
# Average loss per batch: 0.8445449337153368
# Epoch [11/150]
# Training accuracy: 0.6992049217224121
# Average loss per batch: 0.8439004929132865
# Epoch [12/150]
# Training accuracy: 0.7093639373779297
# Average loss per batch: 0.8266145280549224
# Epoch [13/150]
# Training accuracy: 0.7367491126060486
# Average loss per batch: 0.8174389814826805
# Epoch [14/150]
# Training accuracy: 0.7257066965103149
# Average loss per batch: 0.8243274067489195
# Epoch [15/150]
# Training accuracy: 0.7610424160957336
# Average loss per batch: 0.8006818051069555
# Epoch [16/150]
# Training accuracy: 0.7508834004402161
# Average loss per batch: 0.7989983499889642
# Epoch [17/150]
# Training accuracy: 0.7535335421562195
# Average loss per batch: 0.7987814755506919
# Epoch [18/150]
# Training accuracy: 0.7495583295822144
# Average loss per batch: 0.7952091786223399
# Epoch [19/150]
# Training accuracy: 0.7747349739074707
# Average loss per batch: 0.7740128686730291
# Epoch [20/150]
# Training accuracy: 0.791077733039856
# Average loss per batch: 0.7589049007691128
# Epoch [21/150]
# Training accuracy: 0.7915194630622864
# Average loss per batch: 0.7607264057011671
# Epoch [22/150]
# Training accuracy: 0.7822437882423401
# Average loss per batch: 0.7686713270738091
# Epoch [23/150]
# Training accuracy: 0.7897526621818542
# Average loss per batch: 0.761900718363238
# Epoch [24/150]
# Training accuracy: 0.773409903049469
# Average loss per batch: 0.7753384449112584
# Epoch [25/150]
# Training accuracy: 0.7959364056587219
# Average loss per batch: 0.7602990958052622
# Epoch [26/150]
# Training accuracy: 0.7884275913238525
# Average loss per batch: 0.7638769980887292
# Epoch [27/150]
# Training accuracy: 0.7844523191452026
# Average loss per batch: 0.7727322737935564
# Epoch [28/150]
# Training accuracy: 0.8025618195533752
# Average loss per batch: 0.7501230248263184
# Epoch [29/150]
# Training accuracy: 0.8038869500160217
# Average loss per batch: 0.7492088910559533
# Epoch [30/150]
# Training accuracy: 0.7822437882423401
# Average loss per batch: 0.771632968539923
# Epoch [31/150]
# Training accuracy: 0.7950530052185059
# Average loss per batch: 0.7542820702975904
# Epoch [32/150]
# Training accuracy: 0.7844523191452026
# Average loss per batch: 0.7618024172917218
# Epoch [33/150]
# Training accuracy: 0.8087455630302429
# Average loss per batch: 0.7453213795809679
# Epoch [34/150]
# Training accuracy: 0.7875441908836365
# Average loss per batch: 0.7617198367353896
# Epoch [35/150]
# Training accuracy: 0.7981448769569397
# Average loss per batch: 0.7503241136879988
# Epoch [36/150]
# Training accuracy: 0.797703206539154
# Average loss per batch: 0.7570635735149115
# Epoch [37/150]
# Training accuracy: 0.7809187173843384
# Average loss per batch: 0.761220117689858
# Epoch [38/150]
# Training accuracy: 0.8189045786857605
# Average loss per batch: 0.7335651281853797
# Epoch [39/150]
# Training accuracy: 0.8083038926124573
# Average loss per batch: 0.7430334473159951
# Epoch [40/150]
# Training accuracy: 0.7981448769569397
# Average loss per batch: 0.7512770551191249
# Epoch [41/150]
# Training accuracy: 0.8290635943412781
# Average loss per batch: 0.7260013449359948
# Epoch [42/150]
# Training accuracy: 0.8259717226028442
# Average loss per batch: 0.7266660387247381
# Epoch [43/150]
# Training accuracy: 0.8175795078277588
# Average loss per batch: 0.7382862051607857
# Epoch [44/150]
# Training accuracy: 0.7848939895629883
# Average loss per batch: 0.7669387090374047
# Epoch [45/150]
# Training accuracy: 0.7566254138946533
# Average loss per batch: 0.7922120572815479
# Epoch [46/150]
# Training accuracy: 0.8083038926124573
# Average loss per batch: 0.745180608101294
# Epoch [47/150]
# Training accuracy: 0.7857773900032043
# Average loss per batch: 0.7685049184611146
# Epoch [48/150]
# Training accuracy: 0.7985865473747253
# Average loss per batch: 0.7501752628407008
# Epoch [49/150]
# Training accuracy: 0.7990282773971558
# Average loss per batch: 0.7540784843370948
# Epoch [50/150]
# Training accuracy: 0.7928445339202881
# Average loss per batch: 0.7620961485614239
# Epoch [51/150]
# Training accuracy: 0.8034452199935913
# Average loss per batch: 0.7472783793026293
# Epoch [52/150]
# Training accuracy: 0.7950530052185059
# Average loss per batch: 0.7573544991687989
# Epoch [53/150]
# Training accuracy: 0.8109540343284607
# Average loss per batch: 0.7436073703665129
# Epoch [54/150]
# Training accuracy: 0.809628963470459
# Average loss per batch: 0.74282647732278
# Epoch [55/150]
# Training accuracy: 0.8211130499839783
# Average loss per batch: 0.7336758064552092
# Epoch [56/150]
# Training accuracy: 0.7800353169441223
# Average loss per batch: 0.7672621213214498
# Epoch [57/150]
# Training accuracy: 0.8122791647911072
# Average loss per batch: 0.741342370358991
# Epoch [58/150]
# Training accuracy: 0.8078621625900269
# Average loss per batch: 0.7427480455855249
# Epoch [59/150]
# Training accuracy: 0.820229709148407
# Average loss per batch: 0.7339059660132502
# Epoch [60/150]
# Training accuracy: 0.8215547800064087
# Average loss per batch: 0.736633903123963
# Epoch [61/150]
# Training accuracy: 0.7972614765167236
# Average loss per batch: 0.758026918475057
# Epoch [62/150]
# Training accuracy: 0.7769434452056885
# Average loss per batch: 0.7680098741826876
# Epoch [63/150]
# Training accuracy: 0.8065370917320251
# Average loss per batch: 0.7455292524586261
# Epoch [64/150]
# Training accuracy: 0.8228798508644104
# Average loss per batch: 0.7328132046780116
# Epoch [65/150]
# Training accuracy: 0.8286219239234924
# Average loss per batch: 0.725893926452583
# Epoch [66/150]
# Training accuracy: 0.8317137956619263
# Average loss per batch: 0.7214022312365788
# Epoch [67/150]
# Training accuracy: 0.8171378374099731
# Average loss per batch: 0.7337983741726674
# Epoch [68/150]
# Training accuracy: 0.828180193901062
# Average loss per batch: 0.7268327365458851
# Epoch [69/150]
# Training accuracy: 0.8427562117576599
# Average loss per batch: 0.7150423644294202
# Epoch [70/150]
# Training accuracy: 0.809628963470459
# Average loss per batch: 0.7395349119750547
# Epoch [71/150]
# Training accuracy: 0.8299469947814941
# Average loss per batch: 0.7226422244394329
# Epoch [72/150]
# Training accuracy: 0.8440812826156616
# Average loss per batch: 0.7085520713262154
# Epoch [73/150]
# Training accuracy: 0.8458480834960938
# Average loss per batch: 0.7095420944019103
# Epoch [74/150]
# Training accuracy: 0.8334805369377136
# Average loss per batch: 0.7228375413048436
# Epoch [75/150]
# Training accuracy: 0.8409894108772278
# Average loss per batch: 0.7161555168494372
# Epoch [76/150]
# Training accuracy: 0.8246466517448425
# Average loss per batch: 0.7326462810308161
# Epoch [77/150]
# Training accuracy: 0.8122791647911072
# Average loss per batch: 0.7368454811438708
# Epoch [78/150]
# Training accuracy: 0.8295053243637085
# Average loss per batch: 0.7233548919919511
# Epoch [79/150]
# Training accuracy: 0.815371036529541
# Average loss per batch: 0.7298049041083161
# Epoch [80/150]
# Training accuracy: 0.8502650260925293
# Average loss per batch: 0.7068769247599052
# Epoch [81/150]
# Training accuracy: 0.8427562117576599
# Average loss per batch: 0.707543219479037
# Epoch [82/150]
# Training accuracy: 0.8242049217224121
# Average loss per batch: 0.7288766570494208
# Epoch [83/150]
# Training accuracy: 0.8418728113174438
# Average loss per batch: 0.70770927340212
# Epoch [84/150]
# Training accuracy: 0.8286219239234924
# Average loss per batch: 0.7260016291074349
# Epoch [85/150]
# Training accuracy: 0.8268551230430603
# Average loss per batch: 0.7286289502197588
# Epoch [86/150]
# Training accuracy: 0.8078621625900269
# Average loss per batch: 0.7366000413894653
# Epoch [87/150]
# Training accuracy: 0.8321554660797119
# Average loss per batch: 0.7178114954854401
# Epoch [88/150]
# Training accuracy: 0.8242049217224121
# Average loss per batch: 0.7262762927673232
# Epoch [89/150]
# Training accuracy: 0.8312720656394958
# Average loss per batch: 0.7198365511189044
# Epoch [90/150]
# Training accuracy: 0.8365724086761475
# Average loss per batch: 0.7169137853132167
# Epoch [91/150]
# Training accuracy: 0.8069788217544556
# Average loss per batch: 0.740987565735696
# Epoch [92/150]
# Training accuracy: 0.8175795078277588
# Average loss per batch: 0.7319460813428315
# Epoch [93/150]
# Training accuracy: 0.8352473378181458
# Average loss per batch: 0.7150069508754032
# Epoch [94/150]
# Training accuracy: 0.8295053243637085
# Average loss per batch: 0.7272473800350243
# Epoch [95/150]
# Training accuracy: 0.8087455630302429
# Average loss per batch: 0.748715919927812
# Epoch [96/150]
# Training accuracy: 0.8259717226028442
# Average loss per batch: 0.7273459308583972
# Epoch [97/150]
# Training accuracy: 0.797703206539154
# Average loss per batch: 0.7510871723504133
# Epoch [98/150]
# Training accuracy: 0.8060954213142395
# Average loss per batch: 0.740937526796905
# Epoch [99/150]
# Training accuracy: 0.8193463087081909
# Average loss per batch: 0.731071368069716
# Epoch [100/150]
# Training accuracy: 0.8286219239234924
# Average loss per batch: 0.7246602152434873
# Epoch [101/150]
# Training accuracy: 0.8158127069473267
# Average loss per batch: 0.7370808888489092
# Epoch [102/150]
# Training accuracy: 0.8476148247718811
# Average loss per batch: 0.7043976632642074
# Epoch [103/150]
# Training accuracy: 0.8321554660797119
# Average loss per batch: 0.720734824596996
# Epoch [104/150]
# Training accuracy: 0.8595406413078308
# Average loss per batch: 0.6969927117018633
# Epoch [105/150]
# Training accuracy: 0.8635159134864807
# Average loss per batch: 0.6927662815006685
# Epoch [106/150]
# Training accuracy: 0.8537985682487488
# Average loss per batch: 0.6972150387058795
# Epoch [107/150]
# Training accuracy: 0.851590096950531
# Average loss per batch: 0.7003480968341022
# Epoch [108/150]
# Training accuracy: 0.856448769569397
# Average loss per batch: 0.6992002750786257
# Epoch [109/150]
# Training accuracy: 0.8498232960700989
# Average loss per batch: 0.7008256664578344
# Epoch [110/150]
# Training accuracy: 0.8529151678085327
# Average loss per batch: 0.7012247573321974
# Epoch [111/150]
# Training accuracy: 0.8476148247718811
# Average loss per batch: 0.7032833964052335
# Epoch [112/150]
# Training accuracy: 0.8489399552345276
# Average loss per batch: 0.7041149466810092
# Epoch [113/150]
# Training accuracy: 0.8608657121658325
# Average loss per batch: 0.6933331581908213
# Epoch [114/150]
# Training accuracy: 0.8507066965103149
# Average loss per batch: 0.7035318898483062
# Epoch [115/150]
# Training accuracy: 0.8626325130462646
# Average loss per batch: 0.6901273521738993
# Epoch [116/150]
# Training accuracy: 0.856448769569397
# Average loss per batch: 0.6957748372789839
# Epoch [117/150]
# Training accuracy: 0.8582155704498291
# Average loss per batch: 0.6967237033474614
# Epoch [118/150]
# Training accuracy: 0.8630741834640503
# Average loss per batch: 0.693039551587172
# Epoch [119/150]
# Training accuracy: 0.8476148247718811
# Average loss per batch: 0.7070347763283152
# Epoch [120/150]
# Training accuracy: 0.8657243847846985
# Average loss per batch: 0.6880869172828298
# Epoch [121/150]
# Training accuracy: 0.856448769569397
# Average loss per batch: 0.6974115182816143
# Epoch [122/150]
# Training accuracy: 0.8568904399871826
# Average loss per batch: 0.6961204023428367
# Epoch [123/150]
# Training accuracy: 0.8568904399871826
# Average loss per batch: 0.6945814994019521
# Epoch [124/150]
# Training accuracy: 0.8529151678085327
# Average loss per batch: 0.6991432069892615
# Epoch [125/150]
# Training accuracy: 0.8599823117256165
# Average loss per batch: 0.6921165396629925
# Epoch [126/150]
# Training accuracy: 0.8595406413078308
# Average loss per batch: 0.6954153243085028
# Epoch [127/150]
# Training accuracy: 0.8599823117256165
# Average loss per batch: 0.6920623321768263
# Epoch [128/150]
# Training accuracy: 0.8511484265327454
# Average loss per batch: 0.703271468340511
# Epoch [129/150]
# Training accuracy: 0.8696996569633484
# Average loss per batch: 0.6861270237976397
# Epoch [130/150]
# Training accuracy: 0.8582155704498291
# Average loss per batch: 0.6981106442464909
# Epoch [131/150]
# Training accuracy: 0.8586572408676147
# Average loss per batch: 0.6952520965690344
# Epoch [132/150]
# Training accuracy: 0.8635159134864807
# Average loss per batch: 0.6861654624972545
# Epoch [133/150]
# Training accuracy: 0.8789752721786499
# Average loss per batch: 0.6775706649666101
# Epoch [134/150]
# Training accuracy: 0.8586572408676147
# Average loss per batch: 0.6948411128890346
# Epoch [135/150]
# Training accuracy: 0.8683745861053467
# Average loss per batch: 0.6857508169093602
# Epoch [136/150]
# Training accuracy: 0.8608657121658325
# Average loss per batch: 0.690271686919978
# Epoch [137/150]
# Training accuracy: 0.8639575839042664
# Average loss per batch: 0.690756188312047
# Epoch [138/150]
# Training accuracy: 0.8688162565231323
# Average loss per batch: 0.6825213877248092
# Epoch [139/150]
# Training accuracy: 0.8666077852249146
# Average loss per batch: 0.689346862091145
# Epoch [140/150]
# Training accuracy: 0.8542402982711792
# Average loss per batch: 0.7006550972730341
# Epoch [141/150]
# Training accuracy: 0.8635159134864807
# Average loss per batch: 0.6913927759922726
# Epoch [142/150]
# Training accuracy: 0.8454063534736633
# Average loss per batch: 0.7046824685284789
# Epoch [143/150]
# Training accuracy: 0.8714664578437805
# Average loss per batch: 0.6797260398596106
# Epoch [144/150]
# Training accuracy: 0.8529151678085327
# Average loss per batch: 0.6986017907169503
# Epoch [145/150]
# Training accuracy: 0.8529151678085327
# Average loss per batch: 0.6993934726211387
# Epoch [146/150]
# Training accuracy: 0.8679328560829163
# Average loss per batch: 0.6855708885360772
# Epoch [147/150]
# Training accuracy: 0.8696996569633484
# Average loss per batch: 0.6840856440470252
# Epoch [148/150]
# Training accuracy: 0.8617491126060486
# Average loss per batch: 0.6906116436904585
# Epoch [149/150]
# Training accuracy: 0.8674911856651306
# Average loss per batch: 0.6838661142638032
# Epoch [150/150]
# Training accuracy: 0.8546819686889648
# Average loss per batch: 0.6935621999518972
# Training time: 332.75843300199995

# %%
training_accuracies = np.array(batch_accuracies)
batch_losses = np.array(avg_losses_per_batch)

plt.figure()
plt.plot(training_accuracies, color = "m",   label = "Training Accuracy Per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

plt.figure()
plt.plot(batch_losses, color = "g",   label = "Average Loss Per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.legend()
plt.show()

print(f"Training Accuracy: {training_accuracies[-1]}")
# Out:
# Training Accuracy: 0.8546819686889648

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# Testing
acc = Accuracy(task="multiclass", num_classes = classes).to(device)
model.eval()

all_preds = []
all_labels = []
start_time = time.perf_counter()

with torch.no_grad():
   for i, data in enumerate(testing):

       raw_data, labels = data
       labels = torch.squeeze(labels, dim = 1)
       depth_class = model(raw_data.float())
       _, preds = torch.max(depth_class, 1)
       _, truth = torch.max(labels, 1)

       all_preds.extend(preds.cpu().numpy())
       all_labels.extend(truth.cpu().numpy())


       acc(preds, truth)

end_time = time.perf_counter()

testing_time = end_time - start_time
print(f"Testing Time: {(testing_time/969)}")
test_accuracy = acc.compute()
print(f"Test accuracy: {test_accuracy}")

# Generate matrix
cm = confusion_matrix(all_labels, all_preds)

# Plot the matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# Out:
# Testing Time: 0.0005981081558307887
# Test accuracy: 0.9195046424865723

# %%
torch.save(model.state_dict(), "CNN_Origin.pth")
