# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import optim
from torch import nn
from torch.utils.data import DataLoader, TensorDataset, random_split, WeightedRandomSampler
from torch.optim.lr_scheduler import StepLR

from tqdm import tqdm

import torchvision

import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms


# !pip install torchmetrics
from torchmetrics import Accuracy

import time
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (1.9.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (26.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.11.0+cu128)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (0.15.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.15.3->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.29.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.9.6)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->torchmetrics) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
batches = 16

param = 'depth labels'

# Load training data
training_file = 'train.pt'
training_data = torch.load(training_file, map_location = device)
training_waveforms = training_data['raw waves']
training_labels    = training_data[param]
targets = torch.argmax(torch.squeeze(training_labels, dim = 1), dim = 1)
trainingset = TensorDataset(training_waveforms, training_labels)

#Make a sampler
counts = [140, 1100 ,882] # 151, 1231, 882
class_weights = [1/count for count in counts]
sample_weights = [class_weights[t] for t in targets]
sampler = WeightedRandomSampler(
    weights=sample_weights,
    num_samples=len(sample_weights),
    replacement=True
)

training = DataLoader(trainingset, batch_size=batches, sampler=sampler)

# Load testing data
testing_file  = 'test.pt'
testing_data  = torch.load(testing_file, map_location = device)
testing_waveforms = testing_data['raw waves']
testing_labels    = testing_data[param]
testingset  = TensorDataset(testing_waveforms, testing_labels)
testing = DataLoader(testingset, batch_size=batches, shuffle = False)

# %%
classes = 3

# Define Model
class CNN(nn.Module):

    def __init__(self, num_features):
        super(CNN, self).__init__()

        self.conv1   = nn.Conv2d(1,    out_channels = 16,  kernel_size =(3,7), padding ='same')
        self.conv2   = nn.Conv2d(16,   out_channels = 32,  kernel_size =(3,7), padding ='same')
        self.conv3   = nn.Conv2d(32,   out_channels = 64,  kernel_size =(3,7), padding ='same')
        self.pool    = nn.MaxPool2d(kernel_size = 2, stride = 2, padding = 1)
        self.bn1     = nn.BatchNorm2d(16)
        self.bn2     = nn.BatchNorm2d(32)
        self.bn3     = nn.BatchNorm2d(64)
        self.bn4     = nn.BatchNorm2d(128)
        self.bn5     = nn.BatchNorm2d(256)
        self.relu    = nn.ReLU()
        self.softmax = nn.Softmax(dim=-1)
        self.dropout = nn.Dropout(p=0.5)

        self.fullyconnected = nn.LazyLinear(classes)

    def forward(self,x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = torch.flatten(x, start_dim = 1)
        x = self.fullyconnected(x)

        return x

# %%
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)

# %%
# Construct model
model = CNN(classes)
model.to(device)

print(model)

# define optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=0.001)
weights = torch.tensor([3.0, 1.2, 0.7]).to(device)
scheduler = StepLR(optimizer, step_size=150, gamma=0.1)
criterion = nn.CrossEntropyLoss(weight = weights)
# Out:
# CNN(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv2): Conv2d(16, 32, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv3): Conv2d(32, 64, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (softmax): Softmax(dim=-1)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fullyconnected): LazyLinear(in_features=0, out_features=3, bias=True)
# )

# %%
epochs = 250
model.train()

avg_losses_per_batch = []
batch_accuracies = []

start_time = time.perf_counter()

# Training
for epoch in range(epochs):

    accuracy_training = Accuracy(task="multiclass", num_classes = classes).to(device)
    all_preds = []
    all_labels = []
    batch_losses = []
    print(f"Epoch [{epoch + 1}/{epochs}]")

    for i, data in enumerate(training):

        raw_data, labels = data

        labels = torch.squeeze(labels)
        _, truth = torch.max(labels, 1)

        classification = model(raw_data.float())

        _, preds = torch.max(classification, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(truth.cpu().numpy())

        loss = criterion(classification, truth)
        accuracy_training(preds, truth)


        batch_losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    scheduler.step()

    training_accuracy = accuracy_training.compute()
    print(f"Training accuracy: {training_accuracy}")

    batch_accuracies.append(training_accuracy.cpu().item())
    avg_losses_per_batch.append(np.mean(batch_losses))
    print(f"Average loss per batch: {np.mean(batch_losses)}")
end_time = time.perf_counter()
print(f"Training time: {end_time - start_time}")
# Out:
# Epoch [1/250]
# Training accuracy: 0.42667844891548157
# Average loss per batch: 1.2202080496599976
# Epoch [2/250]
# Training accuracy: 0.49160778522491455
# Average loss per batch: 0.9890045485865901
# Epoch [3/250]
# Training accuracy: 0.5136925578117371
# Average loss per batch: 0.8917688057875969
# Epoch [4/250]
# Training accuracy: 0.5353356599807739
# Average loss per batch: 0.8390636534338266
# Epoch [5/250]
# Training accuracy: 0.554770290851593
# Average loss per batch: 0.7991701509331314
# Epoch [6/250]
# Training accuracy: 0.5971731543540955
# Average loss per batch: 0.7350429378344979
# Epoch [7/250]
# Training accuracy: 0.6135159134864807
# Average loss per batch: 0.7080348941012168
# Epoch [8/250]
# Training accuracy: 0.619257926940918
# Average loss per batch: 0.6974049659681992
# Epoch [9/250]
# Training accuracy: 0.6303003430366516
# Average loss per batch: 0.678995285760349
# Epoch [10/250]
# Training accuracy: 0.6223497986793518
# Average loss per batch: 0.6790768719265159
# Epoch [11/250]
# Training accuracy: 0.6241165995597839
# Average loss per batch: 0.6673834831781791
# Epoch [12/250]
# Training accuracy: 0.666077733039856
# Average loss per batch: 0.6226271354186703
# Epoch [13/250]
# Training accuracy: 0.6409010887145996
# Average loss per batch: 0.6481088004271749
# Epoch [14/250]
# Training accuracy: 0.6563604474067688
# Average loss per batch: 0.6219202064922158
# Epoch [15/250]
# Training accuracy: 0.6519434452056885
# Average loss per batch: 0.6439557005192192
# Epoch [16/250]
# Training accuracy: 0.6802120208740234
# Average loss per batch: 0.6166544292174595
# Epoch [17/250]
# Training accuracy: 0.6859540343284607
# Average loss per batch: 0.5968212957008624
# Epoch [18/250]
# Training accuracy: 0.6916961073875427
# Average loss per batch: 0.5853756272666891
# Epoch [19/250]
# Training accuracy: 0.7111307382583618
# Average loss per batch: 0.5615823183890799
# Epoch [20/250]
# Training accuracy: 0.7049469947814941
# Average loss per batch: 0.5934277704693902
# Epoch [21/250]
# Training accuracy: 0.7111307382583618
# Average loss per batch: 0.56685738470143
# Epoch [22/250]
# Training accuracy: 0.7075971961021423
# Average loss per batch: 0.5497884434503568
# Epoch [23/250]
# Training accuracy: 0.7305653691291809
# Average loss per batch: 0.5278801950560489
# Epoch [24/250]
# Training accuracy: 0.7336572408676147
# Average loss per batch: 0.5351748977538565
# Epoch [25/250]
# Training accuracy: 0.7208480834960938
# Average loss per batch: 0.5516030614224958
# Epoch [26/250]
# Training accuracy: 0.75
# Average loss per batch: 0.5024434175919479
# Epoch [27/250]
# Training accuracy: 0.7385159134864807
# Average loss per batch: 0.5149199973109743
# Epoch [28/250]
# Training accuracy: 0.7398409843444824
# Average loss per batch: 0.5024586737050977
# Epoch [29/250]
# Training accuracy: 0.7429328560829163
# Average loss per batch: 0.508772752444509
# Epoch [30/250]
# Training accuracy: 0.7592756152153015
# Average loss per batch: 0.4756082473191577
# Epoch [31/250]
# Training accuracy: 0.7460247278213501
# Average loss per batch: 0.4984547744544459
# Epoch [32/250]
# Training accuracy: 0.7482331991195679
# Average loss per batch: 0.5022199861705303
# Epoch [33/250]
# Training accuracy: 0.768551230430603
# Average loss per batch: 0.45795658346213086
# Epoch [34/250]
# Training accuracy: 0.7623674869537354
# Average loss per batch: 0.4940066035364715
# Epoch [35/250]
# Training accuracy: 0.754858672618866
# Average loss per batch: 0.49686911969747344
# Epoch [36/250]
# Training accuracy: 0.7716431021690369
# Average loss per batch: 0.45665245964913304
# Epoch [37/250]
# Training accuracy: 0.7773851752281189
# Average loss per batch: 0.4612196694115098
# Epoch [38/250]
# Training accuracy: 0.7526502013206482
# Average loss per batch: 0.48170387807866216
# Epoch [39/250]
# Training accuracy: 0.7729681730270386
# Average loss per batch: 0.44609491359180126
# Epoch [40/250]
# Training accuracy: 0.7703180313110352
# Average loss per batch: 0.47575717146547747
# Epoch [41/250]
# Training accuracy: 0.7751767039299011
# Average loss per batch: 0.44582189556578516
# Epoch [42/250]
# Training accuracy: 0.773409903049469
# Average loss per batch: 0.4533654903651963
# Epoch [43/250]
# Training accuracy: 0.7707597017288208
# Average loss per batch: 0.45717322608639654
# Epoch [44/250]
# Training accuracy: 0.7756183743476868
# Average loss per batch: 0.4497055453313908
# Epoch [45/250]
# Training accuracy: 0.7694346308708191
# Average loss per batch: 0.4663469848078741
# Epoch [46/250]
# Training accuracy: 0.8034452199935913
# Average loss per batch: 0.40917755700123143
# Epoch [47/250]
# Training accuracy: 0.7853356599807739
# Average loss per batch: 0.45277933527151465
# Epoch [48/250]
# Training accuracy: 0.7583922147750854
# Average loss per batch: 0.4696389233667246
# Epoch [49/250]
# Training accuracy: 0.7689929604530334
# Average loss per batch: 0.4549539884106374
# Epoch [50/250]
# Training accuracy: 0.7636925578117371
# Average loss per batch: 0.45035211904577804
# Epoch [51/250]
# Training accuracy: 0.7747349739074707
# Average loss per batch: 0.4537908482614537
# Epoch [52/250]
# Training accuracy: 0.7716431021690369
# Average loss per batch: 0.4717644815870994
# Epoch [53/250]
# Training accuracy: 0.7636925578117371
# Average loss per batch: 0.47317904254920046
# Epoch [54/250]
# Training accuracy: 0.778268575668335
# Average loss per batch: 0.42227821582010094
# Epoch [55/250]
# Training accuracy: 0.7694346308708191
# Average loss per batch: 0.4435238347087108
# Epoch [56/250]
# Training accuracy: 0.7765017747879028
# Average loss per batch: 0.4369899727089304
# Epoch [57/250]
# Training accuracy: 0.7857773900032043
# Average loss per batch: 0.414034265132857
# Epoch [58/250]
# Training accuracy: 0.791077733039856
# Average loss per batch: 0.4236142020147871
# Epoch [59/250]
# Training accuracy: 0.8030035495758057
# Average loss per batch: 0.39850466394088635
# Epoch [60/250]
# Training accuracy: 0.7822437882423401
# Average loss per batch: 0.4462714176887358
# Epoch [61/250]
# Training accuracy: 0.7985865473747253
# Average loss per batch: 0.408841352227708
# Epoch [62/250]
# Training accuracy: 0.804770290851593
# Average loss per batch: 0.38336175323372157
# Epoch [63/250]
# Training accuracy: 0.7809187173843384
# Average loss per batch: 0.44507316846243095
# Epoch [64/250]
# Training accuracy: 0.7844523191452026
# Average loss per batch: 0.421967918866537
# Epoch [65/250]
# Training accuracy: 0.8197879791259766
# Average loss per batch: 0.3936189278750352
# Epoch [66/250]
# Training accuracy: 0.8091872930526733
# Average loss per batch: 0.3930052970339295
# Epoch [67/250]
# Training accuracy: 0.7893109321594238
# Average loss per batch: 0.4110408212045129
# Epoch [68/250]
# Training accuracy: 0.7937279343605042
# Average loss per batch: 0.41031132861447167
# Epoch [69/250]
# Training accuracy: 0.8043286204338074
# Average loss per batch: 0.391600725096716
# Epoch [70/250]
# Training accuracy: 0.8118374347686768
# Average loss per batch: 0.3762222568596333
# Epoch [71/250]
# Training accuracy: 0.8003533482551575
# Average loss per batch: 0.3860554105379212
# Epoch [72/250]
# Training accuracy: 0.8158127069473267
# Average loss per batch: 0.3845045143134997
# Epoch [73/250]
# Training accuracy: 0.8043286204338074
# Average loss per batch: 0.3895446971373659
# Epoch [74/250]
# Training accuracy: 0.8065370917320251
# Average loss per batch: 0.3911076053898309
# Epoch [75/250]
# Training accuracy: 0.7999116778373718
# Average loss per batch: 0.4116466007864391
# Epoch [76/250]
# Training accuracy: 0.8083038926124573
# Average loss per batch: 0.3864511454504141
# Epoch [77/250]
# Training accuracy: 0.8021201491355896
# Average loss per batch: 0.38862508797729517
# Epoch [78/250]
# Training accuracy: 0.8162544369697571
# Average loss per batch: 0.3685599778004935
# Epoch [79/250]
# Training accuracy: 0.8122791647911072
# Average loss per batch: 0.39537560231458974
# Epoch [80/250]
# Training accuracy: 0.8043286204338074
# Average loss per batch: 0.3729194058498866
# Epoch [81/250]
# Training accuracy: 0.8030035495758057
# Average loss per batch: 0.3844994895265136
# Epoch [82/250]
# Training accuracy: 0.7875441908836365
# Average loss per batch: 0.4027505750492425
# Epoch [83/250]
# Training accuracy: 0.8189045786857605
# Average loss per batch: 0.34925297178774023
# Epoch [84/250]
# Training accuracy: 0.8197879791259766
# Average loss per batch: 0.35760028403199895
# Epoch [85/250]
# Training accuracy: 0.8078621625900269
# Average loss per batch: 0.3683745899749264
# Epoch [86/250]
# Training accuracy: 0.8087455630302429
# Average loss per batch: 0.36898374932647593
# Epoch [87/250]
# Training accuracy: 0.8149293065071106
# Average loss per batch: 0.3577945644796734
# Epoch [88/250]
# Training accuracy: 0.8264134526252747
# Average loss per batch: 0.36312950438570596
# Epoch [89/250]
# Training accuracy: 0.7994699478149414
# Average loss per batch: 0.411640838155864
# Epoch [90/250]
# Training accuracy: 0.8189045786857605
# Average loss per batch: 0.36840649447600604
# Epoch [91/250]
# Training accuracy: 0.8118374347686768
# Average loss per batch: 0.3750486146186439
# Epoch [92/250]
# Training accuracy: 0.8189045786857605
# Average loss per batch: 0.3659561505593674
# Epoch [93/250]
# Training accuracy: 0.8277385234832764
# Average loss per batch: 0.32795357607095177
# Epoch [94/250]
# Training accuracy: 0.8193463087081909
# Average loss per batch: 0.34856021023539063
# Epoch [95/250]
# Training accuracy: 0.8189045786857605
# Average loss per batch: 0.3706153206999453
# Epoch [96/250]
# Training accuracy: 0.8175795078277588
# Average loss per batch: 0.3801812397342333
# Epoch [97/250]
# Training accuracy: 0.809628963470459
# Average loss per batch: 0.38720979638607567
# Epoch [98/250]
# Training accuracy: 0.8197879791259766
# Average loss per batch: 0.36010514155135187
# Epoch [99/250]
# Training accuracy: 0.8317137956619263
# Average loss per batch: 0.3252819255387909
# Epoch [100/250]
# Training accuracy: 0.8056536912918091
# Average loss per batch: 0.4021885462210212
# Epoch [101/250]
# Training accuracy: 0.828180193901062
# Average loss per batch: 0.34929094199274835
# Epoch [102/250]
# Training accuracy: 0.8060954213142395
# Average loss per batch: 0.38911699839461017
# Epoch [103/250]
# Training accuracy: 0.8317137956619263
# Average loss per batch: 0.3432190634152839
# Epoch [104/250]
# Training accuracy: 0.8286219239234924
# Average loss per batch: 0.36235207660307345
# Epoch [105/250]
# Training accuracy: 0.8348056674003601
# Average loss per batch: 0.3296318227740031
# Epoch [106/250]
# Training accuracy: 0.815371036529541
# Average loss per batch: 0.37044991101597396
# Epoch [107/250]
# Training accuracy: 0.8233215808868408
# Average loss per batch: 0.36360470124218663
# Epoch [108/250]
# Training accuracy: 0.833038866519928
# Average loss per batch: 0.34224550056100733
# Epoch [109/250]
# Training accuracy: 0.8268551230430603
# Average loss per batch: 0.35408676176948445
# Epoch [110/250]
# Training accuracy: 0.837897539138794
# Average loss per batch: 0.31694732280939975
# Epoch [111/250]
# Training accuracy: 0.846731424331665
# Average loss per batch: 0.326248806147036
# Epoch [112/250]
# Training accuracy: 0.8171378374099731
# Average loss per batch: 0.3607244143183802
# Epoch [113/250]
# Training accuracy: 0.8175795078277588
# Average loss per batch: 0.37591180205345154
# Epoch [114/250]
# Training accuracy: 0.8237632513046265
# Average loss per batch: 0.3589878460575997
# Epoch [115/250]
# Training accuracy: 0.8317137956619263
# Average loss per batch: 0.3450410542091433
# Epoch [116/250]
# Training accuracy: 0.8131625652313232
# Average loss per batch: 0.37382067133948
# Epoch [117/250]
# Training accuracy: 0.8264134526252747
# Average loss per batch: 0.3493768198704216
# Epoch [118/250]
# Training accuracy: 0.8250883221626282
# Average loss per batch: 0.3363067803930649
# Epoch [119/250]
# Training accuracy: 0.8401060104370117
# Average loss per batch: 0.3286773087719167
# Epoch [120/250]
# Training accuracy: 0.8343639373779297
# Average loss per batch: 0.33448561484938566
# Epoch [121/250]
# Training accuracy: 0.8228798508644104
# Average loss per batch: 0.36187902649103754
# Epoch [122/250]
# Training accuracy: 0.8233215808868408
# Average loss per batch: 0.34902594369691864
# Epoch [123/250]
# Training accuracy: 0.8233215808868408
# Average loss per batch: 0.3561808905288787
# Epoch [124/250]
# Training accuracy: 0.8361307382583618
# Average loss per batch: 0.3237523218669312
# Epoch [125/250]
# Training accuracy: 0.8255300521850586
# Average loss per batch: 0.3514196881106202
# Epoch [126/250]
# Training accuracy: 0.8458480834960938
# Average loss per batch: 0.33811072752037097
# Epoch [127/250]
# Training accuracy: 0.827296793460846
# Average loss per batch: 0.3533212072675077
# Epoch [128/250]
# Training accuracy: 0.8361307382583618
# Average loss per batch: 0.3506006339013996
# Epoch [129/250]
# Training accuracy: 0.8268551230430603
# Average loss per batch: 0.32659936448375526
# Epoch [130/250]
# Training accuracy: 0.8409894108772278
# Average loss per batch: 0.3202462458956829
# Epoch [131/250]
# Training accuracy: 0.8502650260925293
# Average loss per batch: 0.2992729177095101
# Epoch [132/250]
# Training accuracy: 0.837897539138794
# Average loss per batch: 0.3241511189811666
# Epoch [133/250]
# Training accuracy: 0.8237632513046265
# Average loss per batch: 0.34563705397271355
# Epoch [134/250]
# Training accuracy: 0.8299469947814941
# Average loss per batch: 0.3574335898705561
# Epoch [135/250]
# Training accuracy: 0.8259717226028442
# Average loss per batch: 0.338278903265182
# Epoch [136/250]
# Training accuracy: 0.8683745861053467
# Average loss per batch: 0.26975006156299314
# Epoch [137/250]
# Training accuracy: 0.8405476808547974
# Average loss per batch: 0.3119055859114922
# Epoch [138/250]
# Training accuracy: 0.8299469947814941
# Average loss per batch: 0.3487062305605537
# Epoch [139/250]
# Training accuracy: 0.83878093957901
# Average loss per batch: 0.3195166366214169
# Epoch [140/250]
# Training accuracy: 0.8242049217224121
# Average loss per batch: 0.34600324913019864
# Epoch [141/250]
# Training accuracy: 0.846731424331665
# Average loss per batch: 0.3157640239617354
# Epoch [142/250]
# Training accuracy: 0.8454063534736633
# Average loss per batch: 0.3147161361748274
# Epoch [143/250]
# Training accuracy: 0.8091872930526733
# Average loss per batch: 0.38379439093749707
# Epoch [144/250]
# Training accuracy: 0.8295053243637085
# Average loss per batch: 0.3256527675105862
# Epoch [145/250]
# Training accuracy: 0.83878093957901
# Average loss per batch: 0.305687397744664
# Epoch [146/250]
# Training accuracy: 0.8277385234832764
# Average loss per batch: 0.34938646881828006
# Epoch [147/250]
# Training accuracy: 0.8374558091163635
# Average loss per batch: 0.32752329701374117
# Epoch [148/250]
# Training accuracy: 0.8476148247718811
# Average loss per batch: 0.3307014221823971
# Epoch [149/250]
# Training accuracy: 0.8321554660797119
# Average loss per batch: 0.3249222004759899
# Epoch [150/250]
# Training accuracy: 0.8590989112854004
# Average loss per batch: 0.2996541210515818
# Epoch [151/250]
# Training accuracy: 0.8542402982711792
# Average loss per batch: 0.2912774818988753
# Epoch [152/250]
# Training accuracy: 0.8537985682487488
# Average loss per batch: 0.293152174007305
# Epoch [153/250]
# Training accuracy: 0.8524734973907471
# Average loss per batch: 0.29242184464196663
# Epoch [154/250]
# Training accuracy: 0.8436395525932312
# Average loss per batch: 0.31601099950641814
# Epoch [155/250]
# Training accuracy: 0.8732331991195679
# Average loss per batch: 0.26744744736491377
# Epoch [156/250]
# Training accuracy: 0.856448769569397
# Average loss per batch: 0.28733093703401763
# Epoch [157/250]
# Training accuracy: 0.8586572408676147
# Average loss per batch: 0.2673046483041745
# Epoch [158/250]
# Training accuracy: 0.8648409843444824
# Average loss per batch: 0.2980901824284187
# Epoch [159/250]
# Training accuracy: 0.856448769569397
# Average loss per batch: 0.29367611511334984
# Epoch [160/250]
# Training accuracy: 0.8613074421882629
# Average loss per batch: 0.2789579046968843
# Epoch [161/250]
# Training accuracy: 0.8613074421882629
# Average loss per batch: 0.27901155578995673
# Epoch [162/250]
# Training accuracy: 0.8838339447975159
# Average loss per batch: 0.24614146956518082
# Epoch [163/250]
# Training accuracy: 0.8688162565231323
# Average loss per batch: 0.2761829019340516
# Epoch [164/250]
# Training accuracy: 0.8542402982711792
# Average loss per batch: 0.28603398763168025
# Epoch [165/250]
# Training accuracy: 0.8489399552345276
# Average loss per batch: 0.29232906680029463
# Epoch [166/250]
# Training accuracy: 0.8577738404273987
# Average loss per batch: 0.29344440305205455
# Epoch [167/250]
# Training accuracy: 0.8723497986793518
# Average loss per batch: 0.26087955855043
# Epoch [168/250]
# Training accuracy: 0.8436395525932312
# Average loss per batch: 0.30515674013696925
# Epoch [169/250]
# Training accuracy: 0.8599823117256165
# Average loss per batch: 0.29528800631597846
# Epoch [170/250]
# Training accuracy: 0.8617491126060486
# Average loss per batch: 0.2737222886054029
# Epoch [171/250]
# Training accuracy: 0.8520318269729614
# Average loss per batch: 0.30424540466301037
# Epoch [172/250]
# Training accuracy: 0.8462897539138794
# Average loss per batch: 0.3040385330358232
# Epoch [173/250]
# Training accuracy: 0.8621907830238342
# Average loss per batch: 0.2747478402600112
# Epoch [174/250]
# Training accuracy: 0.8546819686889648
# Average loss per batch: 0.2859894568362916
# Epoch [175/250]
# Training accuracy: 0.8666077852249146
# Average loss per batch: 0.2683174924164171
# Epoch [176/250]
# Training accuracy: 0.8657243847846985
# Average loss per batch: 0.2660125991670598
# Epoch [177/250]
# Training accuracy: 0.8595406413078308
# Average loss per batch: 0.28442792919739873
# Epoch [178/250]
# Training accuracy: 0.8635159134864807
# Average loss per batch: 0.2737432476133108
# Epoch [179/250]
# Training accuracy: 0.8617491126060486
# Average loss per batch: 0.2712108484652995
# Epoch [180/250]
# Training accuracy: 0.8741165995597839
# Average loss per batch: 0.26209624050001445
# Epoch [181/250]
# Training accuracy: 0.8542402982711792
# Average loss per batch: 0.29250817568841536
# Epoch [182/250]
# Training accuracy: 0.8714664578437805
# Average loss per batch: 0.26263130426039577
# Epoch [183/250]
# Training accuracy: 0.8767668008804321
# Average loss per batch: 0.2482776653257684
# Epoch [184/250]
# Training accuracy: 0.8409894108772278
# Average loss per batch: 0.29571658437153403
# Epoch [185/250]
# Training accuracy: 0.8599823117256165
# Average loss per batch: 0.27898440559879994
# Epoch [186/250]
# Training accuracy: 0.8719081282615662
# Average loss per batch: 0.2660301775297701
# Epoch [187/250]
# Training accuracy: 0.8595406413078308
# Average loss per batch: 0.2797983510577133
# Epoch [188/250]
# Training accuracy: 0.8661660552024841
# Average loss per batch: 0.25709055592371544
# Epoch [189/250]
# Training accuracy: 0.8727915287017822
# Average loss per batch: 0.2543681053916963
# Epoch [190/250]
# Training accuracy: 0.8648409843444824
# Average loss per batch: 0.2885557018797582
# Epoch [191/250]
# Training accuracy: 0.8670494556427002
# Average loss per batch: 0.2700921564533467
# Epoch [192/250]
# Training accuracy: 0.8710247278213501
# Average loss per batch: 0.24979104437458682
# Epoch [193/250]
# Training accuracy: 0.851590096950531
# Average loss per batch: 0.2838510302826762
# Epoch [194/250]
# Training accuracy: 0.8643993139266968
# Average loss per batch: 0.27606164527610993
# Epoch [195/250]
# Training accuracy: 0.8670494556427002
# Average loss per batch: 0.2632803117043116
# Epoch [196/250]
# Training accuracy: 0.8670494556427002
# Average loss per batch: 0.27467932306807225
# Epoch [197/250]
# Training accuracy: 0.8820671439170837
# Average loss per batch: 0.24759288577520303
# Epoch [198/250]
# Training accuracy: 0.8639575839042664
# Average loss per batch: 0.27772560622543097
# Epoch [199/250]
# Training accuracy: 0.8648409843444824
# Average loss per batch: 0.2678070359233714
# Epoch [200/250]
# Training accuracy: 0.8657243847846985
# Average loss per batch: 0.27880302713003374
# Epoch [201/250]
# Training accuracy: 0.8666077852249146
# Average loss per batch: 0.26560698275152644
# Epoch [202/250]
# Training accuracy: 0.8829505443572998
# Average loss per batch: 0.2314874198497601
# Epoch [203/250]
# Training accuracy: 0.8568904399871826
# Average loss per batch: 0.2914183565192449
# Epoch [204/250]
# Training accuracy: 0.870141327381134
# Average loss per batch: 0.2546757892771086
# Epoch [205/250]
# Training accuracy: 0.8705830574035645
# Average loss per batch: 0.2530349733465364
# Epoch [206/250]
# Training accuracy: 0.8780918717384338
# Average loss per batch: 0.25337754416240144
# Epoch [207/250]
# Training accuracy: 0.8679328560829163
# Average loss per batch: 0.2595401135220809
# Epoch [208/250]
# Training accuracy: 0.8705830574035645
# Average loss per batch: 0.2558744277175463
# Epoch [209/250]
# Training accuracy: 0.8648409843444824
# Average loss per batch: 0.2588255268351083
# Epoch [210/250]
# Training accuracy: 0.8842756152153015
# Average loss per batch: 0.24716658912546619
# Epoch [211/250]
# Training accuracy: 0.8674911856651306
# Average loss per batch: 0.2582657436879588
# Epoch [212/250]
# Training accuracy: 0.8710247278213501
# Average loss per batch: 0.2590486377241536
# Epoch [213/250]
# Training accuracy: 0.8719081282615662
# Average loss per batch: 0.2745450092873103
# Epoch [214/250]
# Training accuracy: 0.8758834004402161
# Average loss per batch: 0.250601673695508
# Epoch [215/250]
# Training accuracy: 0.8727915287017822
# Average loss per batch: 0.2426981174216514
# Epoch [216/250]
# Training accuracy: 0.8577738404273987
# Average loss per batch: 0.2816862031804319
# Epoch [217/250]
# Training accuracy: 0.8688162565231323
# Average loss per batch: 0.278380416609137
# Epoch [218/250]
# Training accuracy: 0.8811837434768677
# Average loss per batch: 0.24520255158602877
# Epoch [219/250]
# Training accuracy: 0.8714664578437805
# Average loss per batch: 0.2508755719787638
# Epoch [220/250]
# Training accuracy: 0.8590989112854004
# Average loss per batch: 0.26142383692458165
# Epoch [221/250]
# Training accuracy: 0.8723497986793518
# Average loss per batch: 0.25996339849104555
# Epoch [222/250]
# Training accuracy: 0.880742073059082
# Average loss per batch: 0.24284047573070291
# Epoch [223/250]
# Training accuracy: 0.8537985682487488
# Average loss per batch: 0.2912528507385245
# Epoch [224/250]
# Training accuracy: 0.8674911856651306
# Average loss per batch: 0.26587850621468584
# Epoch [225/250]
# Training accuracy: 0.8767668008804321
# Average loss per batch: 0.24129188107326627
# Epoch [226/250]
# Training accuracy: 0.8688162565231323
# Average loss per batch: 0.26458456331837765
# Epoch [227/250]
# Training accuracy: 0.8666077852249146
# Average loss per batch: 0.28922520939942814
# Epoch [228/250]
# Training accuracy: 0.8661660552024841
# Average loss per batch: 0.266877676832529
# Epoch [229/250]
# Training accuracy: 0.8586572408676147
# Average loss per batch: 0.25910736661253525
# Epoch [230/250]
# Training accuracy: 0.8856006860733032
# Average loss per batch: 0.24569648854486958
# Epoch [231/250]
# Training accuracy: 0.8630741834640503
# Average loss per batch: 0.27790310951343306
# Epoch [232/250]
# Training accuracy: 0.8758834004402161
# Average loss per batch: 0.25119105589405544
# Epoch [233/250]
# Training accuracy: 0.8723497986793518
# Average loss per batch: 0.2521573222557109
# Epoch [234/250]
# Training accuracy: 0.8763250708580017
# Average loss per batch: 0.2410768667550784
# Epoch [235/250]
# Training accuracy: 0.8882508873939514
# Average loss per batch: 0.22313771524112408
# Epoch [236/250]
# Training accuracy: 0.869257926940918
# Average loss per batch: 0.25213255641431037
# Epoch [237/250]
# Training accuracy: 0.8696996569633484
# Average loss per batch: 0.25819329083667625
# Epoch [238/250]
# Training accuracy: 0.8838339447975159
# Average loss per batch: 0.2564419417471533
# Epoch [239/250]
# Training accuracy: 0.8727915287017822
# Average loss per batch: 0.2575875288531394
# Epoch [240/250]
# Training accuracy: 0.8679328560829163
# Average loss per batch: 0.261846141391237
# Epoch [241/250]
# Training accuracy: 0.8825088143348694
# Average loss per batch: 0.2421252489791737
# Epoch [242/250]
# Training accuracy: 0.8763250708580017
# Average loss per batch: 0.24065000239208761
# Epoch [243/250]
# Training accuracy: 0.8785335421562195
# Average loss per batch: 0.25431952508113964
# Epoch [244/250]
# Training accuracy: 0.8723497986793518
# Average loss per batch: 0.26684525269280435
# Epoch [245/250]
# Training accuracy: 0.8754416704177856
# Average loss per batch: 0.2545424716048677
# Epoch [246/250]
# Training accuracy: 0.8776502013206482
# Average loss per batch: 0.22698954769088822
# Epoch [247/250]
# Training accuracy: 0.8639575839042664
# Average loss per batch: 0.26328073249159145
# Epoch [248/250]
# Training accuracy: 0.8754416704177856
# Average loss per batch: 0.2570240546253995
# Epoch [249/250]
# Training accuracy: 0.8763250708580017
# Average loss per batch: 0.2538992659792199
# Epoch [250/250]
# Training accuracy: 0.8842756152153015
# Average loss per batch: 0.2338151144991878
# Training time: 176.71311085399998

# %%
training_accuracies = np.array(batch_accuracies)
batch_losses = np.array(avg_losses_per_batch)

plt.figure()
plt.plot(training_accuracies, color = "m",   label = "Training Accuracy Per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

plt.figure()
plt.plot(batch_losses, color = "g",   label = "Average Loss Per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.legend()
plt.show()

print(f"Training Accuracy: {training_accuracies[-1]}")
# Out:
# Training Accuracy: 0.8842756152153015

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# Testing
acc = Accuracy(task="multiclass", num_classes = classes).to(device)
model.eval()

all_preds = []
all_labels = []
start_time = time.perf_counter()

with torch.no_grad():
   for i, data in enumerate(testing):

       raw_data, labels = data
       labels = torch.squeeze(labels, dim = 1)
       depth_class = model(raw_data.float())
       _, preds = torch.max(depth_class, 1)
       _, truth = torch.max(labels, 1)

       all_preds.extend(preds.cpu().numpy())
       all_labels.extend(truth.cpu().numpy())


       acc(preds, truth)

end_time = time.perf_counter()

testing_time = end_time - start_time
print(f"Testing Time: {(testing_time/969)}")
test_accuracy = acc.compute()
print(f"Test accuracy: {test_accuracy}")

# Generate matrix
cm = confusion_matrix(all_labels, all_preds)

# Plot the matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# Out:
# Testing Time: 0.0001265044953560456
# Test accuracy: 0.7450980544090271

# %%
torch.save(model.state_dict(), "CNN_Depth.pth")
