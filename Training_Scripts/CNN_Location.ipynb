# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
from torch import optim
from torch import nn
from torch.utils.data import DataLoader, TensorDataset, random_split, WeightedRandomSampler
from torch.optim.lr_scheduler import StepLR

from tqdm import tqdm

import torchvision

import torch.nn.functional as F
import torchvision.datasets as datasets
import torchvision.transforms as transforms


# !pip install torchmetrics
from torchmetrics import Accuracy

import time
# Out:
# Requirement already satisfied: torchmetrics in /usr/local/lib/python3.12/dist-packages (1.9.0)
# Requirement already satisfied: numpy>1.20.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.0.2)
# Requirement already satisfied: packaging>17.1 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (26.2)
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (2.11.0+cu128)
# Requirement already satisfied: lightning-utilities>=0.15.3 in /usr/local/lib/python3.12/dist-packages (from torchmetrics) (0.15.3)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.15.3->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.29.0)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2025.3.0)
# Requirement already satisfied: cuda-toolkit==12.8.1 in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.1)
# Requirement already satisfied: cuda-bindings<13,>=12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (12.9.6)
# Requirement already satisfied: nvidia-cudnn-cu12==9.19.0.56 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (9.19.0.56)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.28.9 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (2.28.9)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.4.5)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->torchmetrics) (3.6.0)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.4.1)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (11.3.3.83)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (1.13.1.3)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.5.8.93)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.93)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90.* in /usr/local/lib/python3.12/dist-packages (from cuda-toolkit[cublas,cudart,cufft,cufile,cupti,curand,cusolver,cusparse,nvjitlink,nvrtc,nvtx]==12.8.1; platform_system == "Linux"->torch>=2.0.0->torchmetrics) (12.8.90)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings<13,>=12.9.4->torch>=2.0.0->torchmetrics) (1.5.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
batches = 16


param = 'loc class'

training_file = 'train.pt'
training_data = torch.load(training_file, map_location = device)
training_waveforms = training_data['raw waves']
training_labels    = training_data[param]
targets = torch.argmax(torch.squeeze(training_labels, dim = 1), dim = 1)
trainingset = TensorDataset(training_waveforms, training_labels)
training = DataLoader(trainingset, batch_size=batches, shuffle = True)

testing_file  = 'test.pt'
testing_data  = torch.load(testing_file, map_location = device)
testing_waveforms = testing_data['raw waves']
testing_labels    = testing_data[param]
testingset  = TensorDataset(testing_waveforms, testing_labels)
testing = DataLoader(testingset, batch_size=batches, shuffle = False)

# %%
classes = 3

# Define Model
class CNN(nn.Module):

    def __init__(self, num_features):
        super(CNN, self).__init__()

        self.conv1   = nn.Conv2d(1,    out_channels = 16,  kernel_size =(3,7), padding ='same')
        self.conv2   = nn.Conv2d(16,   out_channels = 64,  kernel_size =(3,7), padding ='same')
        self.conv3   = nn.Conv2d(64,   out_channels = 64,  kernel_size =(3,7), padding ='same')
        self.conv4   = nn.Conv2d(64,   out_channels = 128, kernel_size =(3,7), padding ='same')
        self.conv5   = nn.Conv2d(128,  out_channels = 256, kernel_size =(3,7), padding ='same')
        self.pool    = nn.MaxPool2d(kernel_size = 2, stride = 2, padding = 1)
        self.bn1     = nn.BatchNorm2d(16)
        self.bn2     = nn.BatchNorm2d(64)
        self.bn3     = nn.BatchNorm2d(64)
        self.bn4     = nn.BatchNorm2d(128)
        self.bn5     = nn.BatchNorm2d(256)
        self.relu    = nn.ReLU()
        self.softmax = nn.Softmax(dim=-1)
        self.dropout = nn.Dropout(p=0.5)

        self.fullyconnected = nn.LazyLinear(classes)

    def forward(self,x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv2(x)
        x = self.bn2(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv3(x)
        x = self.bn3(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv4(x)
        x = self.bn4(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = self.conv5(x)
        x = self.bn5(x)
        x = self.relu(x)
        x = self.pool(x)
        x = self.dropout(x)

        x = torch.flatten(x, start_dim = 1)
        x = self.fullyconnected(x)
        x = self.softmax(x)

        return x

# %%
torch.manual_seed(0)
torch.cuda.manual_seed(0)
torch.cuda.manual_seed_all(0)

# %%
# Construct model
model = CNN(classes)
model.to(device)

print(model)

# define optimizer and loss function
optimizer = optim.Adam(model.parameters(), lr=0.001)
scheduler = StepLR(optimizer, step_size=30, gamma=0.1)
criterion = nn.CrossEntropyLoss()
# Out:
# CNN(
#   (conv1): Conv2d(1, 16, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv2): Conv2d(16, 64, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv3): Conv2d(64, 64, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv4): Conv2d(64, 128, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (conv5): Conv2d(128, 256, kernel_size=(3, 7), stride=(1, 1), padding=same)
#   (pool): MaxPool2d(kernel_size=2, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn3): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn4): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (bn5): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (softmax): Softmax(dim=-1)
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fullyconnected): LazyLinear(in_features=0, out_features=3, bias=True)
# )

# %%
epochs = 250
model.train()

avg_losses_per_batch = []
batch_accuracies = []

start_time = time.perf_counter()

# Training
for epoch in range(epochs):

    accuracy_training = Accuracy(task="multiclass", num_classes = classes).to(device)
    all_preds = []
    all_labels = []
    batch_losses = []
    print(f"Epoch [{epoch + 1}/{epochs}]")

    for i, data in enumerate(training):

        raw_data, labels = data

        labels = torch.squeeze(labels)
        _, truth = torch.max(labels, 1)

        classification = model(raw_data.float())

        _, preds = torch.max(classification, 1)

        all_preds.extend(preds.cpu().numpy())
        all_labels.extend(truth.cpu().numpy())

        loss = criterion(classification, truth)
        accuracy_training(preds, truth)


        batch_losses.append(loss.item())

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    scheduler.step()

    training_accuracy = accuracy_training.compute()
    print(f"Training accuracy: {training_accuracy}")

    batch_accuracies.append(training_accuracy.cpu().item())
    avg_losses_per_batch.append(np.mean(batch_losses))
    print(f"Average loss per batch: {np.mean(batch_losses)}")
end_time = time.perf_counter()
print(f"Training time: {end_time - start_time}")
# Out:
# Epoch [1/250]
# Training accuracy: 0.4752650260925293
# Average loss per batch: 1.0476878151087694
# Epoch [2/250]
# Training accuracy: 0.5918728113174438
# Average loss per batch: 0.9497851809145699
# Epoch [3/250]
# Training accuracy: 0.6886042356491089
# Average loss per batch: 0.8563380803860409
# Epoch [4/250]
# Training accuracy: 0.8175795078277588
# Average loss per batch: 0.7304742877752008
# Epoch [5/250]
# Training accuracy: 0.8418728113174438
# Average loss per batch: 0.7051916529595013
# Epoch [6/250]
# Training accuracy: 0.8635159134864807
# Average loss per batch: 0.685508882495719
# Epoch [7/250]
# Training accuracy: 0.8727915287017822
# Average loss per batch: 0.676094910208608
# Epoch [8/250]
# Training accuracy: 0.8683745861053467
# Average loss per batch: 0.6828692412712205
# Epoch [9/250]
# Training accuracy: 0.8931095600128174
# Average loss per batch: 0.6559793558758749
# Epoch [10/250]
# Training accuracy: 0.8962014317512512
# Average loss per batch: 0.6536244028051135
# Epoch [11/250]
# Training accuracy: 0.903268575668335
# Average loss per batch: 0.6465534891041231
# Epoch [12/250]
# Training accuracy: 0.8970848321914673
# Average loss per batch: 0.6524166771223847
# Epoch [13/250]
# Training accuracy: 0.9019434452056885
# Average loss per batch: 0.6481537164097101
# Epoch [14/250]
# Training accuracy: 0.8886925578117371
# Average loss per batch: 0.6597400815554069
# Epoch [15/250]
# Training accuracy: 0.9054770469665527
# Average loss per batch: 0.6432018124721419
# Epoch [16/250]
# Training accuracy: 0.9085689187049866
# Average loss per batch: 0.6414254979348518
# Epoch [17/250]
# Training accuracy: 0.9204946756362915
# Average loss per batch: 0.6297903703132146
# Epoch [18/250]
# Training accuracy: 0.9143109321594238
# Average loss per batch: 0.6360203124267955
# Epoch [19/250]
# Training accuracy: 0.892667829990387
# Average loss per batch: 0.6577576054653651
# Epoch [20/250]
# Training accuracy: 0.8869258165359497
# Average loss per batch: 0.6615495178061472
# Epoch [21/250]
# Training accuracy: 0.8957597017288208
# Average loss per batch: 0.6551554333156263
# Epoch [22/250]
# Training accuracy: 0.9023851752281189
# Average loss per batch: 0.6462694377126829
# Epoch [23/250]
# Training accuracy: 0.9156360626220703
# Average loss per batch: 0.6346898687557435
# Epoch [24/250]
# Training accuracy: 0.9302120208740234
# Average loss per batch: 0.6196856221682588
# Epoch [25/250]
# Training accuracy: 0.922703206539154
# Average loss per batch: 0.6272538342106511
# Epoch [26/250]
# Training accuracy: 0.9138692617416382
# Average loss per batch: 0.6355429342095281
# Epoch [27/250]
# Training accuracy: 0.912102460861206
# Average loss per batch: 0.6372155316278968
# Epoch [28/250]
# Training accuracy: 0.9200530052185059
# Average loss per batch: 0.6299159862625767
# Epoch [29/250]
# Training accuracy: 0.9138692617416382
# Average loss per batch: 0.6366344367114591
# Epoch [30/250]
# Training accuracy: 0.9174028038978577
# Average loss per batch: 0.6301535665988922
# Epoch [31/250]
# Training accuracy: 0.9262367486953735
# Average loss per batch: 0.6250659479221827
# Epoch [32/250]
# Training accuracy: 0.9350706934928894
# Average loss per batch: 0.6152484320418935
# Epoch [33/250]
# Training accuracy: 0.9333038926124573
# Average loss per batch: 0.6171543090276315
# Epoch [34/250]
# Training accuracy: 0.9372791647911072
# Average loss per batch: 0.6142140673079961
# Epoch [35/250]
# Training accuracy: 0.9386042356491089
# Average loss per batch: 0.6123225915599877
# Epoch [36/250]
# Training accuracy: 0.940371036529541
# Average loss per batch: 0.6097434389759118
# Epoch [37/250]
# Training accuracy: 0.9430211782455444
# Average loss per batch: 0.6080731518671546
# Epoch [38/250]
# Training accuracy: 0.9412544369697571
# Average loss per batch: 0.6099729701666765
# Epoch [39/250]
# Training accuracy: 0.940371036529541
# Average loss per batch: 0.6092746018523901
# Epoch [40/250]
# Training accuracy: 0.9443463087081909
# Average loss per batch: 0.6062695384025574
# Epoch [41/250]
# Training accuracy: 0.939487636089325
# Average loss per batch: 0.6115486080377874
# Epoch [42/250]
# Training accuracy: 0.9408127069473267
# Average loss per batch: 0.6103150790006342
# Epoch [43/250]
# Training accuracy: 0.9439045786857605
# Average loss per batch: 0.6063344419842035
# Epoch [44/250]
# Training accuracy: 0.9439045786857605
# Average loss per batch: 0.6057030134637591
# Epoch [45/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6036018636864675
# Epoch [46/250]
# Training accuracy: 0.939487636089325
# Average loss per batch: 0.6100619884443955
# Epoch [47/250]
# Training accuracy: 0.9439045786857605
# Average loss per batch: 0.6070682553338332
# Epoch [48/250]
# Training accuracy: 0.9416961073875427
# Average loss per batch: 0.6089060419881848
# Epoch [49/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.6052710052946924
# Epoch [50/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6037616843069104
# Epoch [51/250]
# Training accuracy: 0.945229709148407
# Average loss per batch: 0.6062349576345631
# Epoch [52/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6055344532073383
# Epoch [53/250]
# Training accuracy: 0.9412544369697571
# Average loss per batch: 0.6087779134092196
# Epoch [54/250]
# Training accuracy: 0.9439045786857605
# Average loss per batch: 0.608464392138199
# Epoch [55/250]
# Training accuracy: 0.9447879791259766
# Average loss per batch: 0.6044911477767246
# Epoch [56/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6037508912489448
# Epoch [57/250]
# Training accuracy: 0.945229709148407
# Average loss per batch: 0.6051220381763619
# Epoch [58/250]
# Training accuracy: 0.9412544369697571
# Average loss per batch: 0.6087164492674277
# Epoch [59/250]
# Training accuracy: 0.9386042356491089
# Average loss per batch: 0.6114333851236693
# Epoch [60/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6020972699346677
# Epoch [61/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6031361776338496
# Epoch [62/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6030745153695765
# Epoch [63/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6037453484367317
# Epoch [64/250]
# Training accuracy: 0.945229709148407
# Average loss per batch: 0.6053040388604285
# Epoch [65/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6015567771145995
# Epoch [66/250]
# Training accuracy: 0.9390459656715393
# Average loss per batch: 0.611466110592157
# Epoch [67/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6047397956881725
# Epoch [68/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6000521858813057
# Epoch [69/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.6010759859017922
# Epoch [70/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.601095114375504
# Epoch [71/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6041939162032705
# Epoch [72/250]
# Training accuracy: 0.9509717226028442
# Average loss per batch: 0.600689539187391
# Epoch [73/250]
# Training accuracy: 0.9443463087081909
# Average loss per batch: 0.6069976183730112
# Epoch [74/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6035421658569659
# Epoch [75/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6042129611465293
# Epoch [76/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6040531178595314
# Epoch [77/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6044381235686827
# Epoch [78/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6043882088761934
# Epoch [79/250]
# Training accuracy: 0.9430211782455444
# Average loss per batch: 0.6064118025168567
# Epoch [80/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6032190117197977
# Epoch [81/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6032463605974762
# Epoch [82/250]
# Training accuracy: 0.9500883221626282
# Average loss per batch: 0.6011254107448417
# Epoch [83/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.60441227572065
# Epoch [84/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6031488604109052
# Epoch [85/250]
# Training accuracy: 0.9505300521850586
# Average loss per batch: 0.6014805541072094
# Epoch [86/250]
# Training accuracy: 0.940371036529541
# Average loss per batch: 0.6100069234068964
# Epoch [87/250]
# Training accuracy: 0.9509717226028442
# Average loss per batch: 0.6007421692492256
# Epoch [88/250]
# Training accuracy: 0.9434629082679749
# Average loss per batch: 0.6060885535159581
# Epoch [89/250]
# Training accuracy: 0.9443463087081909
# Average loss per batch: 0.6046326441664092
# Epoch [90/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6023435336603246
# Epoch [91/250]
# Training accuracy: 0.9439045786857605
# Average loss per batch: 0.6059431215407143
# Epoch [92/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6018003888533149
# Epoch [93/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6041132152920038
# Epoch [94/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6009390971190492
# Epoch [95/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.6040725573687487
# Epoch [96/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6055676865745598
# Epoch [97/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6039676582309562
# Epoch [98/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.6011827550303768
# Epoch [99/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6028984550019385
# Epoch [100/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6026672851031935
# Epoch [101/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6051037026123262
# Epoch [102/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.6022845829876375
# Epoch [103/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.6042907980965896
# Epoch [104/250]
# Training accuracy: 0.945229709148407
# Average loss per batch: 0.6042771121145973
# Epoch [105/250]
# Training accuracy: 0.9443463087081909
# Average loss per batch: 0.605855150122038
# Epoch [106/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6027717594529541
# Epoch [107/250]
# Training accuracy: 0.9425795078277588
# Average loss per batch: 0.6082514679767717
# Epoch [108/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6043785495657317
# Epoch [109/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6027993459097096
# Epoch [110/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.6048935815482073
# Epoch [111/250]
# Training accuracy: 0.9425795078277588
# Average loss per batch: 0.6077347666444913
# Epoch [112/250]
# Training accuracy: 0.9443463087081909
# Average loss per batch: 0.6067317984473537
# Epoch [113/250]
# Training accuracy: 0.9505300521850586
# Average loss per batch: 0.5997018058535079
# Epoch [114/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6050344739161747
# Epoch [115/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6019524084010595
# Epoch [116/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6045302043498402
# Epoch [117/250]
# Training accuracy: 0.9443463087081909
# Average loss per batch: 0.6058353097505973
# Epoch [118/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6024097074085558
# Epoch [119/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6019607173724913
# Epoch [120/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6018021610421194
# Epoch [121/250]
# Training accuracy: 0.9434629082679749
# Average loss per batch: 0.6045330452247405
# Epoch [122/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.602839168948187
# Epoch [123/250]
# Training accuracy: 0.9430211782455444
# Average loss per batch: 0.6067637843145451
# Epoch [124/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6030522878740875
# Epoch [125/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6026317829817114
# Epoch [126/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6020831935842272
# Epoch [127/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6042882993187703
# Epoch [128/250]
# Training accuracy: 0.9425795078277588
# Average loss per batch: 0.6079623459930151
# Epoch [129/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6039347291832239
# Epoch [130/250]
# Training accuracy: 0.9447879791259766
# Average loss per batch: 0.6062367680207105
# Epoch [131/250]
# Training accuracy: 0.9421378374099731
# Average loss per batch: 0.607803012283755
# Epoch [132/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.6022439103730968
# Epoch [133/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.603663617456463
# Epoch [134/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6043777117426966
# Epoch [135/250]
# Training accuracy: 0.9443463087081909
# Average loss per batch: 0.6063449525497329
# Epoch [136/250]
# Training accuracy: 0.9505300521850586
# Average loss per batch: 0.6012413413591788
# Epoch [137/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6039218302343933
# Epoch [138/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6043197718304647
# Epoch [139/250]
# Training accuracy: 0.9439045786857605
# Average loss per batch: 0.6055398747115068
# Epoch [140/250]
# Training accuracy: 0.9430211782455444
# Average loss per batch: 0.6064279629311091
# Epoch [141/250]
# Training accuracy: 0.9447879791259766
# Average loss per batch: 0.6056547660223195
# Epoch [142/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6016099780378207
# Epoch [143/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6040034201783193
# Epoch [144/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6044491781315333
# Epoch [145/250]
# Training accuracy: 0.9518551230430603
# Average loss per batch: 0.6004991065448438
# Epoch [146/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6041227847757474
# Epoch [147/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6039603797482772
# Epoch [148/250]
# Training accuracy: 0.9518551230430603
# Average loss per batch: 0.6006782046506103
# Epoch [149/250]
# Training accuracy: 0.9434629082679749
# Average loss per batch: 0.6071714183814089
# Epoch [150/250]
# Training accuracy: 0.9518551230430603
# Average loss per batch: 0.5997164018557105
# Epoch [151/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6025789657109221
# Epoch [152/250]
# Training accuracy: 0.9518551230430603
# Average loss per batch: 0.5996430260194859
# Epoch [153/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.6005962763873625
# Epoch [154/250]
# Training accuracy: 0.9527385234832764
# Average loss per batch: 0.5987758372031468
# Epoch [155/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.6015619291386134
# Epoch [156/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6041371604086647
# Epoch [157/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6040940960528145
# Epoch [158/250]
# Training accuracy: 0.9509717226028442
# Average loss per batch: 0.6013687706329454
# Epoch [159/250]
# Training accuracy: 0.9430211782455444
# Average loss per batch: 0.6075724955175964
# Epoch [160/250]
# Training accuracy: 0.952296793460846
# Average loss per batch: 0.6001854341634563
# Epoch [161/250]
# Training accuracy: 0.9500883221626282
# Average loss per batch: 0.6011902211417615
# Epoch [162/250]
# Training accuracy: 0.9509717226028442
# Average loss per batch: 0.6000569706231775
# Epoch [163/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6023711436231372
# Epoch [164/250]
# Training accuracy: 0.9425795078277588
# Average loss per batch: 0.6082033233743318
# Epoch [165/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6022780281557164
# Epoch [166/250]
# Training accuracy: 0.9505300521850586
# Average loss per batch: 0.6011001337581957
# Epoch [167/250]
# Training accuracy: 0.9509717226028442
# Average loss per batch: 0.6006569392244581
# Epoch [168/250]
# Training accuracy: 0.952296793460846
# Average loss per batch: 0.5995010674839288
# Epoch [169/250]
# Training accuracy: 0.9540635943412781
# Average loss per batch: 0.5989808570331251
# Epoch [170/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.6046493175164075
# Epoch [171/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6051391035738126
# Epoch [172/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6024469212746956
# Epoch [173/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6027942782556507
# Epoch [174/250]
# Training accuracy: 0.9509717226028442
# Average loss per batch: 0.6004563574220093
# Epoch [175/250]
# Training accuracy: 0.9509717226028442
# Average loss per batch: 0.6018475294113159
# Epoch [176/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.6014688233254661
# Epoch [177/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6028928206840032
# Epoch [178/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6039885152393664
# Epoch [179/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.602161167792871
# Epoch [180/250]
# Training accuracy: 0.945229709148407
# Average loss per batch: 0.6054040915529493
# Epoch [181/250]
# Training accuracy: 0.952296793460846
# Average loss per batch: 0.5982423915829457
# Epoch [182/250]
# Training accuracy: 0.9505300521850586
# Average loss per batch: 0.6005440308174617
# Epoch [183/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6004053803396897
# Epoch [184/250]
# Training accuracy: 0.9500883221626282
# Average loss per batch: 0.6004715704582106
# Epoch [185/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6017504036426544
# Epoch [186/250]
# Training accuracy: 0.9425795078277588
# Average loss per batch: 0.6069023793851825
# Epoch [187/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6032036333016946
# Epoch [188/250]
# Training accuracy: 0.9434629082679749
# Average loss per batch: 0.6062267993537473
# Epoch [189/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6045540155659259
# Epoch [190/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6044921690309552
# Epoch [191/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6021461856197303
# Epoch [192/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6041185062536052
# Epoch [193/250]
# Training accuracy: 0.9447879791259766
# Average loss per batch: 0.6051728918518818
# Epoch [194/250]
# Training accuracy: 0.953180193901062
# Average loss per batch: 0.5995409392135244
# Epoch [195/250]
# Training accuracy: 0.9430211782455444
# Average loss per batch: 0.6067027407632747
# Epoch [196/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6027895199580932
# Epoch [197/250]
# Training accuracy: 0.9527385234832764
# Average loss per batch: 0.5987420858631671
# Epoch [198/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6022775618123336
# Epoch [199/250]
# Training accuracy: 0.9540635943412781
# Average loss per batch: 0.5965250222615792
# Epoch [200/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6030203809200878
# Epoch [201/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6032665556585285
# Epoch [202/250]
# Training accuracy: 0.9514134526252747
# Average loss per batch: 0.6005892157554626
# Epoch [203/250]
# Training accuracy: 0.9514134526252747
# Average loss per batch: 0.6000680130132487
# Epoch [204/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.6053271083764626
# Epoch [205/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6019636564691302
# Epoch [206/250]
# Training accuracy: 0.9518551230430603
# Average loss per batch: 0.6001175679791142
# Epoch [207/250]
# Training accuracy: 0.9425795078277588
# Average loss per batch: 0.6078323117444213
# Epoch [208/250]
# Training accuracy: 0.9461130499839783
# Average loss per batch: 0.6047617176049193
# Epoch [209/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.6042095720767975
# Epoch [210/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6018257854690015
# Epoch [211/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6014871039021183
# Epoch [212/250]
# Training accuracy: 0.9553886651992798
# Average loss per batch: 0.5965780783706988
# Epoch [213/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.601453165353184
# Epoch [214/250]
# Training accuracy: 0.9536219239234924
# Average loss per batch: 0.5979849511468914
# Epoch [215/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.6008917286362446
# Epoch [216/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6038023187241084
# Epoch [217/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6036321075869279
# Epoch [218/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.601734179006496
# Epoch [219/250]
# Training accuracy: 0.9483215808868408
# Average loss per batch: 0.6035851311515754
# Epoch [220/250]
# Training accuracy: 0.952296793460846
# Average loss per batch: 0.5988713784117095
# Epoch [221/250]
# Training accuracy: 0.9492049217224121
# Average loss per batch: 0.6001006293464715
# Epoch [222/250]
# Training accuracy: 0.952296793460846
# Average loss per batch: 0.5999464795623027
# Epoch [223/250]
# Training accuracy: 0.9478798508644104
# Average loss per batch: 0.6039549208862681
# Epoch [224/250]
# Training accuracy: 0.9540635943412781
# Average loss per batch: 0.5975337632944886
# Epoch [225/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.6049235954251088
# Epoch [226/250]
# Training accuracy: 0.9500883221626282
# Average loss per batch: 0.602091801838136
# Epoch [227/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6040211126837932
# Epoch [228/250]
# Training accuracy: 0.9518551230430603
# Average loss per batch: 0.5993485236671608
# Epoch [229/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.603503254097952
# Epoch [230/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6026588539842149
# Epoch [231/250]
# Training accuracy: 0.9514134526252747
# Average loss per batch: 0.5998758799593213
# Epoch [232/250]
# Training accuracy: 0.945229709148407
# Average loss per batch: 0.6056096604172613
# Epoch [233/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6024826710492792
# Epoch [234/250]
# Training accuracy: 0.9505300521850586
# Average loss per batch: 0.6009630758157918
# Epoch [235/250]
# Training accuracy: 0.9496466517448425
# Average loss per batch: 0.601606162501053
# Epoch [236/250]
# Training accuracy: 0.9456713795661926
# Average loss per batch: 0.60508228733506
# Epoch [237/250]
# Training accuracy: 0.9505300521850586
# Average loss per batch: 0.601280259834209
# Epoch [238/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6017471421772326
# Epoch [239/250]
# Training accuracy: 0.9447879791259766
# Average loss per batch: 0.6058130830946103
# Epoch [240/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6035863257629771
# Epoch [241/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6035683079504631
# Epoch [242/250]
# Training accuracy: 0.9514134526252747
# Average loss per batch: 0.5999959719852662
# Epoch [243/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6041749354819177
# Epoch [244/250]
# Training accuracy: 0.952296793460846
# Average loss per batch: 0.5972292973122126
# Epoch [245/250]
# Training accuracy: 0.945229709148407
# Average loss per batch: 0.6042567873504799
# Epoch [246/250]
# Training accuracy: 0.9487632513046265
# Average loss per batch: 0.6033558031203041
# Epoch [247/250]
# Training accuracy: 0.9465547800064087
# Average loss per batch: 0.6052463923541593
# Epoch [248/250]
# Training accuracy: 0.9469964504241943
# Average loss per batch: 0.6037988159018504
# Epoch [249/250]
# Training accuracy: 0.9474381804466248
# Average loss per batch: 0.6029660529653791
# Epoch [250/250]
# Training accuracy: 0.9447879791259766
# Average loss per batch: 0.6060211486379865
# Training time: 512.114520326

# %%
training_accuracies = np.array(batch_accuracies)
batch_losses = np.array(avg_losses_per_batch)

plt.figure()
plt.plot(training_accuracies, color = "m",   label = "Training Accuracy Per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

plt.figure()
plt.plot(batch_losses, color = "g",   label = "Average Loss Per Epoch")
plt.xlabel("Epoch")
plt.ylabel("Average Loss")
plt.legend()
plt.show()

print(f"Training Accuracy: {training_accuracies[-1]}")
# Out:
# Training Accuracy: 0.9447879791259766

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# Testing
acc = Accuracy(task="multiclass", num_classes = classes).to(device)
model.eval()

all_preds = []
all_labels = []
start_time = time.perf_counter()

with torch.no_grad():
   for i, data in enumerate(testing):

       raw_data, labels = data
       labels = torch.squeeze(labels, dim = 1)
       depth_class = model(raw_data.float())
       _, preds = torch.max(depth_class, 1)
       _, truth = torch.max(labels, 1)

       all_preds.extend(preds.cpu().numpy())
       all_labels.extend(truth.cpu().numpy())


       acc(preds, truth)

end_time = time.perf_counter()

testing_time = end_time - start_time
print(f"Testing Time: {(testing_time/969)}")
test_accuracy = acc.compute()
print(f"Test accuracy: {test_accuracy}")

# Generate matrix
cm = confusion_matrix(all_labels, all_preds)

# Plot the matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# Out:
# Testing Time: 0.0005778992920537063
# Test accuracy: 0.9535603523254395

# %%
torch.save(model.state_dict(), "CNN_Location.pth")
